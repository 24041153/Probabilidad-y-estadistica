# %% [markdown]
# <a href="https://colab.research.google.com/github/24041153/Probabilidad-y-estadistica/blob/main/AutosDatset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1
# ### Practica 6: Estadística descriptiva del Dataset Autos
# ### Facilitador*: Dr. Jose Gabriel Rodrigez Rivas*
# ### Alumno: *Diego Avila Beltran*

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
from matplotlib import pyplot
from statistics import mode

# %%
autos = pd.read_csv("autos2.csv", encoding = "ISO-8859-1")

# %%
autos.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
# 2          1              122.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
Minimo = autos.price.min()
Maximo = autos.price.max()
Moda = mode(autos.price)
Mediana = autos.price.median()
Media = autos.price.mean()
Desviacion = autos.price.std()

print("Minimo =", Minimo)
print("Maximo =", Maximo)
print("Moda =", Moda)
print("Mediana = ", Mediana)
print("Media=", Media )
print("Desviacion =", Desviacion)
# Out:
# Minimo = 5118.0
# Maximo = 45400.0
# Moda = 16500.0
# Mediana =  10295.0
# Media= 13207.129353233831
# Desviacion = 7947.066341939271

# %%
autos.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         205.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          31.681008    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.300000   64.100000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000
# 75%      2.000000         137.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  201.000000  201.000000
# mean    53.724878  2555.565854   126.907317    3.329751    3.255423
# std      2.443522   520.680204    41.642693    0.273539    0.316717
# ...

# %%
import math

n = len(autos.price)
k = int( n + math.log2(10))
print("Valor n = ", n , "\nNumero de intervalos =" , k)
# Out:
# Valor n =  205
# Numero de intervalos = 208

# %%
media = autos.price.mean()

plt.pyplot.hist(autos.price, bins =20)
plt.pyplot.title("Histograma de precios Autodata Set")
plt.pyplot.axvline(media, color="y", linestyle="dashed", linewidth=2, label=f"Media={media:.2f}")
plt.pyplot.xlabel("Precio")
plt.pyplot.ylabel("Fruecuencia")

# En el histograma se muestran las veces que se repite un valor en especifico
# Out:
# Text(0, 0.5, 'Fruecuencia')

# %%
sns.boxplot(x="body-style", y="price", data=autos)
plt.title("Distribución de precios por tipo de vehiculo")
plt.show()

# Muestra la distribución de precios, con medianas y cuartiles

# %%
sns.boxplot(x='drive-wheels', y='price', data=autos)
plt.title("Distribución de precios por tipo de tracción")
plt.show()

# Visualizacion diferencias de precios según el sistema de tracción de los autos

# %%
sns.boxplot(x='engine-location', y="price", data=autos)
plt.title("Relacion entre el precio y la localizacion del motor ")
plt.show()

# Comparacion entre la ubicacion de el motor (En frente y Hacia Atras) y la frecuencia de precios
