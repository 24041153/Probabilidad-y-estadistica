# %% [markdown]
# <a href="https://colab.research.google.com/github/24041153/Probabilidad-y-estadistica/blob/main/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1
# ### Practica 1-2: Estadística descriptiva básica e Histogramas
# ### Facilitador*: Dr. Jose Gabriel Rodrigez Rivas*
# ### Alumno: *Diego Avila Beltran*

# %%
import random

fabrica1 = []
for i in range(1000):
 numero_aleatorio = round( random.uniform(50, 100) , 2)
 fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [83.02, 51.34, 56.36, 87.86, 79.14, 92.73, 96.92, 78.88, 58.48, 64.28, 65.63, 98.98, 91.32, 95.32, 99.17, 84.55, 99.43, 96.4, 93.44, 95.06, 57.78, 94.01, 74.73, 51.07, 53.7, 69.41, 59.54, 71.95, 67.91, 98.38, 88.16, 61.3, 95.22, 89.83, 97.71, 96.54, 81.66, 89.07, 72.21, 55.1, 92.32, 76.32, 66.19, 81.04, 88.42, 60.46, 77.79, 83.76, 97.12, 61.03, 70.83, 69.78, 72.29, 78.46, 80.04, 89.4, 68.29, 94.62, 74.03, 96.87, 67.41, 61.28, 68.36, 80.83, 84.05, 52.45, 63.74, 96.8, 83.4, 74.44, 96.84, 69.41, 79.43, 83.26, 61.16, 67.7, 82.52, 84.81, 71.11, 77.23, 84.16, 74.04, 52.71, 60.96, 93.62, 65.86, 56.2, 59.65, 63.86, 77.43, 67.2, 68.89, 51.83, 85.92, 69.79, 89.5, 92.53, 66.32, 54.2, 74.69, 73.78, 67.68, 90.23, 97.38, 75.56, 88.42, 51.66, 52.92, 79.76, 74.61, 84.77, 94.49, 94.55, 59.17, 62.56, 95.43, 86.79, 84.58, 84.46, 75.29, 67.84, 76.76, 97.0, 90.16, 90.72, 93.39, 66.52, 55.97, 93.72, 70.89, 97.32, 52.68, 65.74, 66.11, 62.99, 76.39, 66.87, 95.76, 87.35, 69.27, 84.76, 99.45, 75.69, 56.04, 87
# ...

# %%
fabrica2 = []
for i in range(100):
 numero_aleatorio2 = round( random.uniform(50, 100) , 2)
 fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [65.48, 61.74, 96.03, 55.44, 92.73, 80.63, 97.45, 66.16, 84.81, 95.09, 99.88, 90.95, 60.71, 97.9, 97.23, 80.3, 79.38, 63.82, 70.15, 92.34, 92.31, 74.5, 89.11, 86.59, 63.11, 60.51, 96.4, 59.58, 85.0, 75.19, 51.92, 50.19, 98.53, 85.95, 66.87, 74.25, 57.72, 82.31, 54.25, 55.19, 71.67, 86.98, 54.89, 76.7, 75.55, 78.0, 61.12, 53.18, 70.56, 60.41, 72.32, 55.97, 73.64, 67.19, 87.39, 97.73, 95.04, 81.71, 90.84, 81.1, 50.7, 78.84, 92.25, 78.95, 57.89, 83.06, 70.15, 51.26, 96.41, 57.1, 53.74, 57.28, 80.47, 98.41, 89.5, 94.1, 96.09, 77.53, 81.15, 74.08, 58.66, 82.26, 51.65, 75.96, 91.59, 62.68, 66.05, 73.6, 50.77, 58.49, 73.84, 54.05, 80.0, 58.77, 85.96, 89.47, 50.73, 67.75, 71.22, 82.81]

# %%
# Libreria de python para graficas
import matplotlib.pyplot as plt

plt.hist(fabrica1)
plt.title("Produccion de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion de la fabrica 2')

# %%
from statistics import mean, median, mode

media = mean(fabrica1)
mediana = median(fabrica1)
moda = mode(fabrica1)

print(" Valores de la fabrica 1")
print( "La media es", media)
print("La mediana es", mediana)
print("La moda es", moda)
# Out:
#  Valores de la fabrica 1
# La media es 74.7521
# La mediana es 74.85499999999999
# La moda es 72.21

# %%
from statistics import mean, median, mode

media = mean(fabrica2)
mediana = median(fabrica2)
moda = mode(fabrica2)

print(" Valores de la fabrica 2")
print( "La media es", media)
print("La mediana es", mediana)
print("La moda es", moda)
# Out:
#  Valores de la fabrica 2
# La media es 74.8496
# La mediana es 75.37
# La moda es 70.15

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

plt.hist(fabrica1, bins=20, alpha=0.2, color="b", edgecolor = "black")
plt.axvline(media1, color="b", linestyle="dashed" , linewidth=2, label="Media")
plt.axvline(mediana1, color="r", linestyle="dashed" , linewidth=2, label="Mediana")
plt.axvline(moda1, color="y", linestyle="dashed" , linewidth=2, label="Moda")
plt.xlabel("Valorde produccion")
plt.ylabel("Fruecuencia")
plt.title("Produccion de la fabrica 1")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

plt.hist(fabrica2, bins=20, alpha=0.2, color="b", edgecolor = "black")
plt.axvline(media2, color="b", linestyle="dashed" , linewidth=2, label="Media")
plt.axvline(mediana2, color="r", linestyle="dashed" , linewidth=2, label="Mediana")
plt.axvline(moda2, color="y", linestyle="dashed" , linewidth=2, label="Moda")
plt.xlabel("Valorde produccion")
plt.ylabel("Fruecuencia")
plt.title("Produccion de la fabrica 2")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
