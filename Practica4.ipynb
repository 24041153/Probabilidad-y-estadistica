# %% [markdown]
# <a href="https://colab.research.google.com/github/24041153/Probabilidad-y-estadistica/blob/main/Practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1
# ### Practica 4 y 5: Tabla de frecuecia, regla de Sturges y diagramas de cajas y bigotes
# ### Facilitador*: Dr. Jose Gabriel Rodrigez Rivas
# ### Alumno: *Diego Avila Beltran*

# %%
import random
edades = []
for i in range(100):
  numero_aleatorio = random.randint(18,70)
  edades.append(numero_aleatorio)
  print(edades)
# Out:
# [62]
# [62, 66]
# [62, 66, 19]
# [62, 66, 19, 22]
# [62, 66, 19, 22, 51]
# [62, 66, 19, 22, 51, 27]
# [62, 66, 19, 22, 51, 27, 38]
# [62, 66, 19, 22, 51, 27, 38, 64]
# [62, 66, 19, 22, 51, 27, 38, 64, 27]
# [62, 66, 19, 22, 51, 27, 38, 64, 27, 41]
# [62, 66, 19, 22, 51, 27, 38, 64, 27, 41, 49]
# [62, 66, 19, 22, 51, 27, 38, 64, 27, 41, 49, 44]
# [62, 66, 19, 22, 51, 27, 38, 64, 27, 41, 49, 44, 60]
# [62, 66, 19, 22, 51, 27, 38, 64, 27, 41, 49, 44, 60, 44]
# [62, 66, 19, 22, 51, 27, 38, 64, 27, 41, 49, 44, 60, 44, 47]
# [62, 66, 19, 22, 51, 27, 38, 64, 27, 41, 49, 44, 60, 44, 47, 56]
# [62, 66, 19, 22, 51, 27, 38, 64, 27, 41, 49, 44, 60, 44, 47, 56, 19]
# [62, 66, 19, 22, 51, 27, 38, 64, 27, 41, 49, 44, 60, 44, 47, 56, 19, 61]
# [62, 66, 19, 22, 51, 27, 38, 64, 27, 41, 49, 44, 60, 44, 47, 56, 19, 61, 43]
# [62, 66, 19, 22, 51, 27, 38, 64, 27, 41, 49, 44, 60, 44, 47, 56, 19, 61, 43, 61]
# [62, 66, 19, 22, 51, 27, 38, 64, 27, 41, 49, 44, 60, 44, 47, 56, 19, 61, 43, 61, 54]
# ...

# %%
import pandas as pd

df = pd.DataFrame(edades, columns=["Edad"])
df.head()
# Out:
#    Edad
# 0    62
# 1    66
# 2    19
# 3    22
# 4    51

# %%
tabla_frecuencia = df["Edad"].value_counts().reset_index()
tabla_frecuencia.columns = ["Edad", "Fruecuencia"]
tabla_frecuencia = tabla_frecuencia.sort_values(by="Edad")
print("Tavla de distribucion de frecuencias:")
tabla_frecuencia
# Out:
# Tavla de distribucion de frecuencias:
#     Edad  Fruecuencia
# 33    18            1
# 6     19            4
# 27    21            2
# 25    22            2
# 11    24            3
# 9     25            3
# 14    26            3
# 15    27            3
# 5     28            4
# 37    29            1
# 32    30            1
# 40    31            1
# 2     32            4
# 45    33            1
# 10    35            3
# 22    36            2
# 28    37            1
# 13    38            3
# 12    39            3
# 30    40            1
# 19    41            2
# 29    42            1
# 26    43            2
# 1     44            4
# 24    46            2
# 17    47            3
# 20    48            2
# 43    49            1
# 35    50            1
# 18    51            3
# 3     53            4
# 41    54            1
# 4     55            4
# 21    56            2
# 7     57            3
# 36    59            1
# 42    60            1
# 16    61            3
# 0     62            4
# ...

# %%
tabla_frecuencia["Frec Relativa"] = tabla_frecuencia["Fruecuencia"]/100
tabla_frecuencia
# Out:
#     Edad  Fruecuencia  Frec Relativa
# 33    18            1           0.01
# 6     19            4           0.04
# 27    21            2           0.02
# 25    22            2           0.02
# 11    24            3           0.03
# 9     25            3           0.03
# 14    26            3           0.03
# 15    27            3           0.03
# 5     28            4           0.04
# 37    29            1           0.01
# 32    30            1           0.01
# 40    31            1           0.01
# 2     32            4           0.04
# 45    33            1           0.01
# 10    35            3           0.03
# 22    36            2           0.02
# 28    37            1           0.01
# 13    38            3           0.03
# 12    39            3           0.03
# 30    40            1           0.01
# 19    41            2           0.02
# 29    42            1           0.01
# 26    43            2           0.02
# 1     44            4           0.04
# ...

# %%
tabla_frecuencia["Frec Relativa"] = tabla_frecuencia["Fruecuencia"]/100 * 100
tabla_frecuencia
# Out:
#     Edad  Fruecuencia  Frec Relativa
# 33    18            1            1.0
# 6     19            4            4.0
# 27    21            2            2.0
# 25    22            2            2.0
# 11    24            3            3.0
# 9     25            3            3.0
# 14    26            3            3.0
# 15    27            3            3.0
# 5     28            4            4.0
# 37    29            1            1.0
# 32    30            1            1.0
# 40    31            1            1.0
# 2     32            4            4.0
# 45    33            1            1.0
# 10    35            3            3.0
# 22    36            2            2.0
# 28    37            1            1.0
# 13    38            3            3.0
# 12    39            3            3.0
# 30    40            1            1.0
# 19    41            2            2.0
# 29    42            1            1.0
# 26    43            2            2.0
# 1     44            4            4.0
# ...

# %%
tabla_frecuencia["Frec Relativa"] = tabla_frecuencia["Fruecuencia"].cumsum()
tabla_frecuencia
# Out:
#     Edad  Fruecuencia  Frec Relativa
# 33    18            1              1
# 6     19            4              5
# 27    21            2              7
# 25    22            2              9
# 11    24            3             12
# 9     25            3             15
# 14    26            3             18
# 15    27            3             21
# 5     28            4             25
# 37    29            1             26
# 32    30            1             27
# 40    31            1             28
# 2     32            4             32
# 45    33            1             33
# 10    35            3             36
# 22    36            2             38
# 28    37            1             39
# 13    38            3             42
# 12    39            3             45
# 30    40            1             46
# 19    41            2             48
# 29    42            1             49
# 26    43            2             51
# 1     44            4             55
# ...

# %%
import math
print(edades)
# Out:
# [62, 66, 19, 22, 51, 27, 38, 64, 27, 41, 49, 44, 60, 44, 47, 56, 19, 61, 43, 61, 54, 47, 57, 44, 55, 26, 19, 31, 39, 36, 59, 36, 55, 51, 46, 53, 57, 53, 63, 24, 21, 19, 55, 32, 38, 35, 25, 41, 39, 69, 21, 55, 26, 65, 25, 29, 28, 62, 70, 38, 57, 51, 46, 43, 69, 24, 48, 25, 42, 47, 67, 35, 50, 32, 32, 56, 37, 66, 53, 28, 44, 28, 48, 24, 18, 62, 53, 39, 30, 32, 61, 40, 22, 27, 62, 35, 26, 69, 33, 28]

# %%
df = pd.DataFrame({"Edad": edades})
df
# Out:
#     Edad
# 0     62
# 1     66
# 2     19
# 3     22
# 4     51
# ..   ...
# 95    35
# 96    26
# 97    69
# 98    33
# 99    28
#
# [100 rows x 1 columns]

# %%
n = len(edades)
k = int( i + math.log2(10))
print("Valor n = ", n , "\nNumero de intervalos =" , k)
# Out:
# Valor n =  100
# Numero de intervalos = 102

# %%
tabla_frecuencia = pd.cut(df["Edad"], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ["Clase", "Frec"]
tabla_frecuencia
# Out:
#                 Clase  Frec
# 0    (52.667, 53.176]     4
# 1    (31.765, 32.275]     4
# 2    (54.706, 55.216]     4
# 3    (27.686, 28.196]     4
# 4       (43.49, 44.0]     4
# ..                ...   ...
# 97   (51.647, 52.157]     0
# 98   (52.157, 52.667]     0
# 99   (53.176, 53.686]     0
# 100  (29.216, 29.725]     0
# 101     (44.0, 44.51]     0
#
# [102 rows x 2 columns]

# %%
tabla_frecuencia = tabla_frecuencia.sort_values(by="Clase")
tabla_frecuencia
# Out:
#                Clase  Frec
# 39   (17.947, 18.51]     1
# 5     (18.51, 19.02]     4
# 72   (19.02, 19.529]     0
# 68  (19.529, 20.039]     0
# 66  (20.039, 20.549]     0
# ..               ...   ...
# 69  (67.451, 67.961]     0
# 70  (67.961, 68.471]     0
# 71   (68.471, 68.98]     0
# 17    (68.98, 69.49]     3
# 40     (69.49, 70.0]     1
#
# [102 rows x 2 columns]

# %%
tabla_frecuencia["frec Rel"] = tabla_frecuencia["Frec"]/n
tabla_frecuencia["frec Porc"] = tabla_frecuencia["Frec"]/ n * 100
tabla_frecuencia["frec Ac"] = tabla_frecuencia["Frec"].cumsum()
tabla_frecuencia["frec Real Ac"] = tabla_frecuencia["Frec"].cumsum()
tabla_frecuencia["frec Porc Ac"] = tabla_frecuencia["Frec"].cumsum()

print(tabla_frecuencia)
# Out:
#                Clase  Frec  frec Rel  frec Porc  frec Ac  frec Real Ac  \
# 39   (17.947, 18.51]     1      0.01        1.0        1             1
# 5     (18.51, 19.02]     4      0.04        4.0        5             5
# 72   (19.02, 19.529]     0      0.00        0.0        5             5
# 68  (19.529, 20.039]     0      0.00        0.0        5             5
# 66  (20.039, 20.549]     0      0.00        0.0        5             5
# ..               ...   ...       ...        ...      ...           ...
# 69  (67.451, 67.961]     0      0.00        0.0       96            96
# 70  (67.961, 68.471]     0      0.00        0.0       96            96
# 71   (68.471, 68.98]     0      0.00        0.0       96            96
# 17    (68.98, 69.49]     3      0.03        3.0       99            99
# 40     (69.49, 70.0]     1      0.01        1.0      100           100
#
#     frec Porc Ac
# 39             1
# 5              5
# 72             5
# 68             5
# 66             5
# ...

# %%
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades")
plt.show()

# %%
plt.hist(df['Edad'], bins =k, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
edades2=[]
for i in range(100):
  numero_aleatorio=random.randint(20,87)
  edades2.append(numero_aleatorio)
print(edades2)
# Out:
# [25, 41, 61, 49, 73, 53, 49, 75, 46, 72, 44, 65, 53, 36, 49, 41, 34, 34, 64, 54, 69, 54, 29, 33, 25, 64, 22, 21, 57, 67, 37, 30, 83, 84, 34, 59, 47, 75, 42, 23, 37, 40, 79, 67, 67, 22, 52, 50, 57, 61, 58, 41, 23, 36, 40, 28, 37, 78, 43, 31, 78, 35, 50, 77, 66, 24, 72, 44, 51, 28, 84, 71, 46, 49, 29, 36, 73, 70, 35, 67, 54, 24, 42, 87, 27, 87, 72, 51, 23, 50, 40, 50, 78, 79, 61, 61, 67, 33, 61, 70]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('Edades Encuesta 2')

plt.show()

# %%
edades.append(130)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('Edades Encuesta 2')

plt.show()
